# %%
from openai import OpenAI
import requests
import json
import pandas as pd
import jieba
from typing import List, Dict,Tuple
import os
from tenacity import retry, stop_after_attempt, wait_exponential
from concurrent.futures import ThreadPoolExecutor

# deepseek
# client = OpenAI(
#     api_key="sk-2fcb2f476ae4463aae2486b99b9f85cc",
#     base_url="https://api.deepseek.com",
# )
# models="deepseek-reasoner"

# 腾讯
client = OpenAI(
    api_key="sk-oervjTZRRbLCCP7Jpl70siJcaJYtF4aDEiJSwTPfsebJv3BF",
    base_url="https://api.lkeap.cloud.tencent.com/v1",
)
models="deepseek-r1"

# %%
from typing import List

MAX_CHUNK = 500  # 分块大小
OVERLAP = 50     # 重叠字符数

def fast_chunk_to_list(txt_path: str) -> List[str]:
    """正确实现重叠分块"""
    if MAX_CHUNK <= OVERLAP:
        raise ValueError("MAX_CHUNK必须大于OVERLAP")
    
    chunks = []
    buffer = ""
    
    with open(txt_path, 'r', encoding='utf-8') as f:
        for line in f:
            buffer += line.strip()  # 根据需求可保留换行符
            
            # 当缓冲区足够大时持续分块
            while len(buffer) >= MAX_CHUNK:
                # 取前MAX_CHUNK字符作为当前块
                chunks.append(buffer[:MAX_CHUNK])
                
                # 保留最后OVERLAP字符作为重叠部分
                # 注意：保留的是 [MAX_CHUNK-OVERLAP : MAX_CHUNK] 这部分
                buffer = buffer[MAX_CHUNK - OVERLAP:]
    
    # 处理剩余内容
    if buffer:
        chunks.append(buffer)
    
    return chunks

# %%
# -------------------- API调用处理 --------------------
@retry(stop=stop_after_attempt(3), wait=wait_exponential(multiplier=1, min=2, max=10))
def call_tencent_api(chunk: str) -> dict:
    try:
        print(chunk)
        prompt = f"""请从以下文本提取知识图谱信息：
        1. 识别关系：源实体、目标实体、关系类型
        格式要求：
        - 关系：("源实体|目标实体|关系类型)
        2.下面这种情况就提取中文，例如：污染源（Pollution Sources），只提取污染源作为实体，不提取括号里面的英文
        3.尽可能多的提取到关系
        4.输出保证是：("源实体|目标实体|关系类型)的格式
        5.输出文本直接给出关系，关系间分行，不要其他内容,只要关系
        文本内容：{chunk.replace(" ","")}"""
        completion = client.chat.completions.create(
            model=models,
            messages=[
                {"role": "system", "content": "你是一个专业的知识图谱构建助手"},
                {"role": "user", "content": prompt}
            ]
        )
        
        result = parse_response(completion)
        print(result)
        # 添加原文验证信息
        for rel in result["relationships"]:
            rel["source_text"] = chunk
        return result
    except Exception as e:
        print("========================================")
        print(e)
        return {"entities": [], "relationships": []}

def parse_response(response) -> dict:
    relationships = []
#     full_text = (response.choices[0].message.reasoning_content or "") + "\n" + (response.choices[0].message.content or "")
    full_text = response.choices[0].message.content
    
    for line in full_text.split('\n'):
        line = line.strip()
        parts = line.split('|')
        if len(parts) >= 3:
                relationships.append({
                    "source": parts[0].strip().upper(),
                    "target": parts[1].strip().upper(),
                    "rel_type": parts[2].strip(),
                })
    return {"relationships": relationships}

# %%
import time
# -------------------- 主流程 --------------------
def build_knowledge_graph(txt_path: str, processed_name: str):
    # 1. 提取文本分块
    text_chunks = fast_chunk_to_list(txt_path)
    print(f"总块数：{len(text_chunks)}")
    
    # 2. 并行处理分块
    all_relationships = []
    
    with ThreadPoolExecutor(max_workers=1) as executor:
        futures = [executor.submit(call_tencent_api, chunk) for chunk in text_chunks]
        
        for future in futures:
            try:
                result = future.result()
                all_relationships.extend(result["relationships"])
            except Exception as e:
                print(f"处理失败：{str(e)}")

    # 3. 数据处理和保存
    if all_relationships:
        df_rels = pd.DataFrame(all_relationships).drop_duplicates(
            subset=['source', 'target', 'rel_type', 'source_text']
        )
        df_rels['label'] = processed_name
        # 保存包含原文验证的结果
        df_rels.to_csv(f"./result/{processed_name}_relationships.csv", index=False)
        print(f"已保存结果到：{processed_name}_relationships.csv")

# -------------------- 文件批量处理 --------------------
def process_txt_files(folder_path: str):
    """处理文件夹下所有TXT文件"""
    count=1
    for root, _, files in os.walk(folder_path):
        for filename in files:
            if filename.lower().endswith('.txt'):
                file_path = os.path.join(root, filename)
                # 处理文件名
                name_part = os.path.splitext(filename)[0]
                processed_name = name_part.split()[-1] if len(name_part.split()) >= 2 else name_part
                processed_name=str(count)+"_"+processed_name
                print(f"正在处理文件：{filename}，标识名称：{processed_name}")
                build_knowledge_graph(file_path, processed_name)
                count+=1

# %%
# 执行处理
process_txt_files("./kg_txt/")

# %%
# 合并结果
import glob

folder_path = './result/'

all_files = glob.glob(folder_path + "/*.csv")
dfs = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    dfs.append(df)
df = pd.concat(dfs, axis=0, ignore_index=True)

# %%
import re
df['rel_type']=df['rel_type']
df['开始节点类型']=df['label'].apply(lambda x:re.sub(r"[^\u4e00-\u9fff]", "", x))
df['结束节点类型']=df['label'].apply(lambda x:re.sub(r"[^\u4e00-\u9fff]", "", x))
df['开始节点']=df['source'].apply(lambda x:re.sub(r"[^\u4e00-\u9fff]", "", x))
df['结束节点']=df['target'].apply(lambda x:re.sub(r"[^\u4e00-\u9fff]", "", x))
df['关系']=df['rel_type'].apply(lambda x:re.sub(r"[^\u4e00-\u9fff]", "", x))
# 开始节点，结束节点，关系，都只提取长度小于20的
df = df[~df.apply(lambda row: any(len(row[col]) > 20 for col in ['开始节点','关系','结束节点']), axis=1)]

df=df.drop_duplicates(
    subset=['开始节点', '关系', '结束节点'],  # 指定要判断重复的列
    keep='first'  # 保留第一个出现的重复项
)

# %%
import re
import difflib

def fuzzy_contains(sentence, entity, threshold=0.8):
    """
    判断 sentence 中是否存在与 entity 相似度超过 threshold 的子串，
    如果存在，返回 True；否则返回 False。
    先判断精确包含，再采用滑动窗口进行模糊匹配。
    """
    # 精确匹配直接返回 True
    if entity in sentence:
        return True
    n = len(entity)
    # 尝试长度在 [n-1, n+1] 范围内的子串匹配
    for length in range(max(n-1, 1), n+2):
        for i in range(0, len(sentence) - length + 1):
            substr = sentence[i:i+length]
            ratio = difflib.SequenceMatcher(None, entity, substr).ratio()
            if ratio >= threshold:
                return True
    return False

def extract_entity_relation_context(text, entity1, entity2, threshold=0.7):
    """
    从文本中提取包含两个目标实体（entity1 和 entity2）的完整上下文。
    - 如果两实体在同一句中（模糊匹配），则返回该完整句子；
    - 否则返回包含两者的最小连续句块。
    """
    # 按中文句号、问号、感叹号分割文本，并保留句子结束符
    sentences = re.split(r'(?<=[。！？])', text)
    sentences = [s.strip() for s in sentences if s.strip()]  # 去除空白

    # 优先查找同时包含两个实体的句子（采用模糊匹配）
    for sentence in sentences:
        if fuzzy_contains(sentence, entity1, threshold) and fuzzy_contains(sentence, entity2, threshold):
            return sentence

    # 分别记录包含 entity1 与 entity2 的句子索引（模糊匹配）
    indices_entity1 = [i for i, s in enumerate(sentences) if fuzzy_contains(s, entity1, threshold)]
    indices_entity2 = [i for i, s in enumerate(sentences) if fuzzy_contains(s, entity2, threshold)]

    # 如果任一实体都未出现，则返回 None
    if not indices_entity1 or not indices_entity2:
        return text

    # 寻找最小的连续句子块，该块中两实体分别出现（模糊匹配）
    best_start, best_end = None, None
    best_length = float('inf')
    for i in indices_entity1:
        for j in indices_entity2:
            start = min(i, j)
            end = max(i, j)
            length = end - start + 1
            if length < best_length:
                best_length = length
                best_start, best_end = start, end

    context_block = ''.join(sentences[best_start:best_end+1])
    return context_block

# %%
df['文本'] = df.apply(
    lambda x: extract_entity_relation_context(x['source_text'], x['开始节点'], x['结束节点']),
    axis=1
)
df=df[['开始节点','开始节点类型','关系','结束节点','结束节点类型',"文本"]]
df=df.dropna()
df.to_csv("result.csv",index=False)

# %%
from py2neo import Graph, Node, Relationship, NodeMatcher, RelationshipMatcher
import os
import csv
import pandas as pd
def get_node_by_name(g, node_type, name):

    matcher = NodeMatcher(g)
    endnode = matcher.match(node_type, name=name).first()
    print(endnode)
    if endnode != None:
        return endnode
    else:
        return None


def get_str_by_dict(mydict):
    last = ""
    print(mydict)
    print(type(mydict))
    for key in mydict:
        last = str(key) + ":" + str(mydict[key]) + "<br>" + last
    return last


g = Graph("bolt://localhost:7687", user="neo4j", password="123456")
#从删库到跑路
cypher = 'MATCH (n) OPTIONAL MATCH (n)-[r]-() DELETE n,r'
g.run(cypher)


df=pd.read_csv("result.csv")

for index,row in df.iterrows():
   try:
        start_name = row["开始节点"]
        start_type = row["开始节点类型"].strip()
        relation = row["关系"]
        end_name = row["结束节点"]
        end_type = row["结束节点类型"].strip()
        print(row)
        start_obj = get_node_by_name(g, start_type, start_name)
        if start_obj == None:
            start_obj = Node(start_type,
                             name=start_name
                             )
            g.create(start_obj)
        # =====
        end_obj = get_node_by_name(g, end_type, end_name)
        if end_obj == None:
            end_obj = Node(end_type,
                           name=end_name
                           )
            g.create(end_obj)
        rel = Relationship(start_obj, relation, end_obj)
        g.create(rel)
   except:
        continue
# Out:
# 开始节点                                                 制药建设项目
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                                 化学药品制造
# 结束节点类型                                               制药建设项目
# 文本        3.9 制药建设项目 pharmaceutical constructional proje...
# Name: 0, dtype: object
# None
# None
# 开始节点                                                 制药建设项目
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                               生物生化制品制造
# 结束节点类型                                               制药建设项目
# 文本        3.9 制药建设项目 pharmaceutical constructional proje...
# Name: 1, dtype: object
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                                 制药建设项目
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                              单纯药品分装和复配
# 结束节点类型                                               制药建设项目
# 文本        3.9 制药建设项目 pharmaceutical constructional proje...
# Name: 2, dtype: object
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                                 制药建设项目
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                           中药饮片加工和中成药制造
# 结束节点类型                                               制药建设项目
# 文本        3.9 制药建设项目 pharmaceutical constructional proje...
# Name: 3, dtype: object
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                                   生产车间
# 开始节点类型                                               制药建设项目
# 关系                                                       属于
# 结束节点                                                 制药生产企业
# 结束节点类型                                               制药建设项目
# 文本        3.11 生产车间 production workshop 制药生产企业下属的、由生产装置组...
# Name: 4, dtype: object
# None
# None
# 开始节点                                                生产装置
# 开始节点类型                                            制药建设项目
# 关系                                                    包含
# 结束节点                                                工艺单元
# 结束节点类型                                            制药建设项目
# 文本        3.12 生产装置 process plant 一个或一个以上相互关联的生产工艺单元的组合。
# Name: 5, dtype: object
# None
# None
# 开始节点                                                   辅助设施
# 开始节点类型                                               制药建设项目
# 关系                                                       属于
# 结束节点                                                   制药企业
# 结束节点类型                                               制药建设项目
# 文本        3.14 辅助设施 auxiliary facility 制药企业内提供水、电、蒸汽等的设施...
# Name: 6, dtype: object
# None
# None
# 开始节点                                                     炮制
# 开始节点类型                                               制药建设项目
# 关系                                                       属于
# 结束节点                                           中药饮片加工和中成药制造
# 结束节点类型                                               制药建设项目
# 文本        3.9 制药建设项目 pharmaceutical constructional proje...
# Name: 7, dtype: object
# None
# (_103:制药建设项目 {name: '\u4e2d\u836f\u996e\u7247\u52a0\u5de5\u548c\u4e2d\u6210\u836f\u5236\u9020'})
# 开始节点                                                 环境敏感区域
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                       建设项目环境影响评价分类管理名录
# 结束节点类型                                               制药建设项目
# 文本        3.17 环境敏感区域 environmental sensitive area 指由《建设...
# Name: 8, dtype: object
# None
# None
# 开始节点                                                   环境因素
# 开始节点类型                                               制药建设项目
# 关系                                                       影响
# 结束节点                                                 环境敏感区域
# 结束节点类型                                               制药建设项目
# 文本        3.16 环境因素 environmental factor 各种天然的和经过人工改造的自然...
# Name: 9, dtype: object
# None
# (_126:制药建设项目 {name: '\u73af\u5883\u654f\u611f\u533a\u57df'})
# 开始节点                                             环境影响评价工作程序
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                HJ/T2.1
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 10, dtype: object
# None
# None
# 开始节点                                             环境影响评价工作程序
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                  HJ2.2
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 11, dtype: object
# (_141:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u5de5\u4f5c\u7a0b\u5e8f'})
# None
# 开始节点                                             环境影响评价工作程序
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                HJ/T2.3
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 12, dtype: object
# (_141:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u5de5\u4f5c\u7a0b\u5e8f'})
# None
# 开始节点                                             环境影响评价工作程序
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                  HJ2.4
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 13, dtype: object
# (_141:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u5de5\u4f5c\u7a0b\u5e8f'})
# None
# 开始节点                                                环境影响因素
# 开始节点类型                                              制药建设项目
# 关系                                                      包含
# 结束节点                                                    废水
# 结束节点类型                                              制药建设项目
# 文本        制药建设项目建设、运行过程中影响环境的因素主要包括：占地，排放的废水、 废气、噪声、固体废物等。
# Name: 14, dtype: object
# None
# None
# 开始节点                                                环境影响因素
# 开始节点类型                                              制药建设项目
# 关系                                                      包含
# 结束节点                                                    废气
# 结束节点类型                                              制药建设项目
# 文本        制药建设项目建设、运行过程中影响环境的因素主要包括：占地，排放的废水、 废气、噪声、固体废物等。
# Name: 15, dtype: object
# (_146:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u56e0\u7d20'})
# None
# 开始节点                                                环境影响因素
# 开始节点类型                                              制药建设项目
# 关系                                                      包含
# 结束节点                                                    噪声
# 结束节点类型                                              制药建设项目
# 文本        制药建设项目建设、运行过程中影响环境的因素主要包括：占地，排放的废水、 废气、噪声、固体废物等。
# Name: 16, dtype: object
# (_146:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u56e0\u7d20'})
# None
# 开始节点                                                环境影响因素
# 开始节点类型                                              制药建设项目
# 关系                                                      包含
# 结束节点                                                  固体废物
# 结束节点类型                                              制药建设项目
# 文本        制药建设项目建设、运行过程中影响环境的因素主要包括：占地，排放的废水、 废气、噪声、固体废物等。
# Name: 17, dtype: object
# (_146:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u56e0\u7d20'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                             化学需氧量（COD）
# 结束节点类型                                               制药建设项目
# 文本        制药建设项目评价因子除废水、废气污染物常规指标[如化学需氧量（COD）、氨氮、 总磷、非甲烷...
# Name: 18, dtype: object
# None
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                                     氨氮
# 结束节点类型                                               制药建设项目
# 文本        制药建设项目评价因子除废水、废气污染物常规指标[如化学需氧量（COD）、氨氮、 总磷、非甲烷...
# Name: 19, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                                     总磷
# 结束节点类型                                               制药建设项目
# 文本        制药建设项目评价因子除废水、废气污染物常规指标[如化学需氧量（COD）、氨氮、 总磷、非甲烷...
# Name: 20, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                            非甲烷总烃（NMHC）
# 结束节点类型                                               制药建设项目
# 文本        制药建设项目评价因子除废水、废气污染物常规指标[如化学需氧量（COD）、氨氮、 总磷、非甲烷...
# Name: 21, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                                   恶臭气体
# 结束节点类型                                               制药建设项目
# 文本        制药建设项目评价因子除废水、废气污染物常规指标[如化学需氧量（COD）、氨氮、 总磷、非甲烷...
# Name: 22, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                          国家或地方法规标准限制排放
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 23, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                              污染物排放总量控制
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 24, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                       持久性有机污染物（POPS）公约
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 25, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                                 三致毒理特性
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 26, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                                 恶臭影响特征
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 27, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                   评价因子
# 开始节点类型                                               制药建设项目
# 关系                                                       符合
# 结束节点                                              环境影响特征污染物
# 结束节点类型                                               制药建设项目
# 文本        符合下列基本原则之一的，应作为评价因子： a）国家或地方法规、标准中限制排放的； b）国家或...
# Name: 28, dtype: object
# (_151:制药建设项目 {name: '\u8bc4\u4ef7\u56e0\u5b50'})
# None
# 开始节点                                                 环境功能区划
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                 HJ/T14
# 结束节点类型                                               制药建设项目
# 文本        b）环境功能区划尚未划定的，其环境功能区标准按HJ/T 14、GB/T 15190、HJ/T...
# Name: 29, dtype: object
# None
# None
# 开始节点                                                 环境功能区划
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                              GB/T15190
# 结束节点类型                                               制药建设项目
# 文本        b）环境功能区划尚未划定的，其环境功能区标准按HJ/T 14、GB/T 15190、HJ/T...
# Name: 30, dtype: object
# (_112:制药建设项目 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# None
# 开始节点                                                 环境功能区划
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                HJ/T338
# 结束节点类型                                               制药建设项目
# 文本        b）环境功能区划尚未划定的，其环境功能区标准按HJ/T 14、GB/T 15190、HJ/T...
# Name: 31, dtype: object
# (_112:制药建设项目 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# None
# 开始节点                                                   评价标准
# 开始节点类型                                               制药建设项目
# 关系                                                     优先采用
# 结束节点                                                   地方标准
# 结束节点类型                                               制药建设项目
# 文本        主要包括国家或地方环境质量标准、国家或地方污染物排放标准等相关标准；选取 评价标准的原则是：...
# Name: 32, dtype: object
# None
# None
# 开始节点                                                   评价标准
# 开始节点类型                                               制药建设项目
# 关系                                                     其次采用
# 结束节点                                                   国家标准
# 结束节点类型                                               制药建设项目
# 文本        主要包括国家或地方环境质量标准、国家或地方污染物排放标准等相关标准；选取 评价标准的原则是：...
# Name: 33, dtype: object
# (_116:制药建设项目 {name: '\u8bc4\u4ef7\u6807\u51c6'})
# None
# 开始节点                                                   评价标准
# 开始节点类型                                               制药建设项目
# 关系                                                     再次采用
# 结束节点                                                   参照标准
# 结束节点类型                                               制药建设项目
# 文本        主要包括国家或地方环境质量标准、国家或地方污染物排放标准等相关标准；选取 评价标准的原则是：...
# Name: 34, dtype: object
# (_116:制药建设项目 {name: '\u8bc4\u4ef7\u6807\u51c6'})
# None
# 开始节点                                                 评价工作等级
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                  HJ2.2
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 35, dtype: object
# None
# (_143:制药建设项目 {name: 'HJ2.2'})
# 开始节点                                                 评价工作等级
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                HJ/T2.3
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 36, dtype: object
# (_159:制药建设项目 {name: '\u8bc4\u4ef7\u5de5\u4f5c\u7b49\u7ea7'})
# (_144:制药建设项目 {name: 'HJ/T2.3'})
# 开始节点                                                 评价工作等级
# 开始节点类型                                               制药建设项目
# 关系                                                       依据
# 结束节点                                                  HJ2.4
# 结束节点类型                                               制药建设项目
# 文本        4.2 环境影响评价工作程序 制药建设项目环境影响评价工作程序应按HJ/T 2.1、HJ 2...
# Name: 37, dtype: object
# (_159:制药建设项目 {name: '\u8bc4\u4ef7\u5de5\u4f5c\u7b49\u7ea7'})
# (_145:制药建设项目 {name: 'HJ2.4'})
# 开始节点                                评价工作等级
# 开始节点类型                              制药建设项目
# 关系                                      依据
# 结束节点                               HJ/T169
# 结束节点类型                              制药建设项目
# 文本        4.5.3 环境风险评价等级。按照HJ/T 169中的规定执行。
# Name: 38, dtype: object
# (_159:制药建设项目 {name: '\u8bc4\u4ef7\u5de5\u4f5c\u7b49\u7ea7'})
# None
# 开始节点                                                HJ/T169
# 开始节点类型                                               制药建设项目
# 关系                                                       规定
# 结束节点                                                 环境敏感目标
# 结束节点类型                                               制药建设项目
# 文本        按照HJ/T 169中的规定执行。4.6.2 环境敏感目标 附表说明评价范围内各环境因素的环...
# Name: 39, dtype: object
# (_160:制药建设项目 {name: 'HJ/T169'})
# None
# 开始节点                                             HJ611—2011
# 开始节点类型                                               制药建设项目
# 关系                                                       规范
# 结束节点                                                 制药建设项目
# 结束节点类型                                               制药建设项目
# 文本        a）大气环境影响评价范围图应标出环境空气监测点； b）地表水环境影响评价范围图应标出监测断面...
# Name: 40, dtype: object
# None
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# 开始节点                                                 评价范围彩图
# 开始节点类型                                               制药建设项目
# 关系                                                       标注
# 结束节点                                                 环境敏感目标
# 结束节点类型                                               制药建设项目
# 文本        4.6.2 环境敏感目标 附表说明评价范围内各环境因素的环境功能类别或级别、各环境因素敏感保...
# Name: 41, dtype: object
# None
# (_161:制药建设项目 {name: '\u73af\u5883\u654f\u611f\u76ee\u6807'})
# 开始节点                                                环境影响报告书
# 开始节点类型                                               制药建设项目
# 关系                                                     必须设置
# 结束节点                                                   工程分析
# 结束节点类型                                               制药建设项目
# 文本        4.7.2 编制环境影响报告表的制药建设项目，可根据具体情况设置工程分析、环境保护措施等专题...
# Name: 42, dtype: object
# None
# None
# 开始节点                                                环境影响报告书
# 开始节点类型                                               制药建设项目
# 关系                                                     选择设置
# 结束节点                                                 环境风险评价
# 结束节点类型                                               制药建设项目
# 文本        a）大气环境影响评价范围图应标出环境空气监测点； b）地表水环境影响评价范围图应标出监测断面...
# Name: 43, dtype: object
# (_173:制药建设项目 {name: '\u73af\u5883\u5f71\u54cd\u62a5\u544a\u4e66'})
# None
# 开始节点                                                环境影响报告表
# 开始节点类型                                               制药建设项目
# 关系                                                     重点评价
# 结束节点                                                   工程分析
# 结束节点类型                                               制药建设项目
# 文本        4.7.2 编制环境影响报告表的制药建设项目，可根据具体情况设置工程分析、环境保护措施等专题...
# Name: 44, dtype: object
# None
# (_174:制药建设项目 {name: '\u5de5\u7a0b\u5206\u6790'})
# 开始节点                                                 环境敏感目标
# 开始节点类型                                               制药建设项目
# 关系                                                     位置关系
# 结束节点                                                 制药建设项目
# 结束节点类型                                               制药建设项目
# 文本        4.6.2 环境敏感目标 附表说明评价范围内各环境因素的环境功能类别或级别、各环境因素敏感保...
# Name: 45, dtype: object
# (_161:制药建设项目 {name: '\u73af\u5883\u654f\u611f\u76ee\u6807'})
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# 开始节点                                                 评价范围彩图
# 开始节点类型                                               制药建设项目
# 关系                                                       标出
# 结束节点                                                  环境监测点
# 结束节点类型                                               制药建设项目
# 文本        a）大气环境影响评价范围图应标出环境空气监测点； b）地表水环境影响评价范围图应标出监测断面...
# Name: 46, dtype: object
# (_162:制药建设项目 {name: '\u8bc4\u4ef7\u8303\u56f4\u5f69\u56fe'})
# None
# 开始节点                                                 环境风险评价
# 开始节点类型                                               制药建设项目
# 关系                                                     标出范围
# 结束节点                                                  环境敏感区
# 结束节点类型                                               制药建设项目
# 文本        a）大气环境影响评价范围图应标出环境空气监测点； b）地表水环境影响评价范围图应标出监测断面...
# Name: 47, dtype: object
# (_163:制药建设项目 {name: '\u73af\u5883\u98ce\u9669\u8bc4\u4ef7'})
# None
# 开始节点                                               地区经济发展状况
# 开始节点类型                                               制药建设项目
# 关系                                                       影响
# 结束节点                                                 制药建设项目
# 结束节点类型                                               制药建设项目
# 文本        包括地区经济发展状况、居住区及人口数量、企事业单位及人员规模、相对于 制药建设项目的方位和距...
# Name: 48, dtype: object
# None
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# 开始节点                                                    居住区
# 开始节点类型                                               制药建设项目
# 关系                                                       包含
# 结束节点                                                   人口数量
# 结束节点类型                                               制药建设项目
# 文本        包括地区经济发展状况、居住区及人口数量、企事业单位及人员规模、相对于 制药建设项目的方位和距...
# Name: 49, dtype: object
# None
# None
# 开始节点                                                  企事业单位
# 开始节点类型                                               制药建设项目
# 关系                                                       统计
# 结束节点                                                   人员规模
# 结束节点类型                                               制药建设项目
# 文本        包括地区经济发展状况、居住区及人口数量、企事业单位及人员规模、相对于 制药建设项目的方位和距...
# Name: 50, dtype: object
# None
# None
# 开始节点                                                 制药建设项目
# 开始节点类型                                               制药建设项目
# 关系                                                       邻近
# 结束节点                                                 文物保护遗址
# 结束节点类型                                               制药建设项目
# 文本        包括地区经济发展状况、居住区及人口数量、企事业单位及人员规模、相对于 制药建设项目的方位和距...
# Name: 51, dtype: object
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                                 区域污染源
# 开始节点类型                                              制药建设项目
# 关系                                                      涉及
# 结束节点                                                环境功能区划
# 结束节点类型                                              制药建设项目
# 文本        c）区域污染源。调查内容按HJ 2.2和HJ/T 2.3执行。d）环境功能区划及生态功能区划等。
# Name: 52, dtype: object
# None
# (_112:制药建设项目 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# 开始节点                 环境功能区划
# 开始节点类型               制药建设项目
# 关系                       相关
# 结束节点                 生态功能区划
# 结束节点类型               制药建设项目
# 文本        d）环境功能区划及生态功能区划等。
# Name: 53, dtype: object
# (_112:制药建设项目 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# None
# 开始节点                                                   调查方法
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                                   现场踏查
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 54, dtype: object
# None
# None
# 开始节点                                                   调查方法
# 开始节点类型                                               制药建设项目
# 关系                                                       包括
# 结束节点                                                 相关部门走访
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 55, dtype: object
# (_183:制药建设项目 {name: '\u8c03\u67e5\u65b9\u6cd5'})
# None
# 开始节点                                                   调查方法
# 开始节点类型                                               制药建设项目
# 关系                                                       收集
# 结束节点                                                    水系图
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 56, dtype: object
# (_183:制药建设项目 {name: '\u8c03\u67e5\u65b9\u6cd5'})
# None
# 开始节点                                                   调查方法
# 开始节点类型                                               制药建设项目
# 关系                                                       收集
# 结束节点                                                  土地利用图
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 57, dtype: object
# (_183:制药建设项目 {name: '\u8c03\u67e5\u65b9\u6cd5'})
# None
# 开始节点                                                 企业现状调查
# 开始节点类型                                               制药建设项目
# 关系                                                       涵盖
# 结束节点                                                   生产车间
# 结束节点类型                                               制药建设项目
# 文本        6 企业现状调查 6.1 调查范围 调查范围包括建设单位所属的、与制药建设项目位于同一区域的...
# Name: 58, dtype: object
# None
# (_104:制药建设项目 {name: '\u751f\u4ea7\u8f66\u95f4'})
# 开始节点                                                 企业现状调查
# 开始节点类型                                               制药建设项目
# 关系                                                       涵盖
# 结束节点                                                   辅助设施
# 结束节点类型                                               制药建设项目
# 文本        6 企业现状调查 6.1 调查范围 调查范围包括建设单位所属的、与制药建设项目位于同一区域的...
# Name: 59, dtype: object
# (_168:制药建设项目 {name: '\u4f01\u4e1a\u73b0\u72b6\u8c03\u67e5'})
# (_123:制药建设项目 {name: '\u8f85\u52a9\u8bbe\u65bd'})
# 开始节点                                                生产车间
# 开始节点类型                                            制药建设项目
# 关系                                                    产生
# 结束节点                                                废气排放
# 结束节点类型                                            制药建设项目
# 文本        了解并说明生产车间（或装置）和辅助设施废水排放去向，企业废水外排口数量、外排口排水最终去向。
# Name: 60, dtype: object
# (_104:制药建设项目 {name: '\u751f\u4ea7\u8f66\u95f4'})
# None
# 开始节点                                                生产车间
# 开始节点类型                                            制药建设项目
# 关系                                                    产生
# 结束节点                                                废水排放
# 结束节点类型                                            制药建设项目
# 文本        了解并说明生产车间（或装置）和辅助设施废水排放去向，企业废水外排口数量、外排口排水最终去向。
# Name: 61, dtype: object
# (_104:制药建设项目 {name: '\u751f\u4ea7\u8f66\u95f4'})
# None
# 开始节点                                                   生产车间
# 开始节点类型                                               制药建设项目
# 关系                                                       产生
# 结束节点                                                   固体废物
# 结束节点类型                                               制药建设项目
# 文本        了解并说明生产车间（或装置）和辅助设施废水排放去向，企业废水外排口数量、外排口排水最终去向。...
# Name: 62, dtype: object
# (_104:制药建设项目 {name: '\u751f\u4ea7\u8f66\u95f4'})
# (_150:制药建设项目 {name: '\u56fa\u4f53\u5e9f\u7269'})
# 开始节点                                                辅助设施
# 开始节点类型                                            制药建设项目
# 关系                                                    产生
# 结束节点                                                废气排放
# 结束节点类型                                            制药建设项目
# 文本        了解并说明生产车间（或装置）和辅助设施废水排放去向，企业废水外排口数量、外排口排水最终去向。
# Name: 63, dtype: object
# (_123:制药建设项目 {name: '\u8f85\u52a9\u8bbe\u65bd'})
# (_187:制药建设项目 {name: '\u5e9f\u6c14\u6392\u653e'})
# 开始节点                                                辅助设施
# 开始节点类型                                            制药建设项目
# 关系                                                    产生
# 结束节点                                                废水排放
# 结束节点类型                                            制药建设项目
# 文本        了解并说明生产车间（或装置）和辅助设施废水排放去向，企业废水外排口数量、外排口排水最终去向。
# Name: 64, dtype: object
# (_123:制药建设项目 {name: '\u8f85\u52a9\u8bbe\u65bd'})
# (_188:制药建设项目 {name: '\u5e9f\u6c34\u6392\u653e'})
# 开始节点                                                   辅助设施
# 开始节点类型                                               制药建设项目
# 关系                                                       产生
# 结束节点                                                   固体废物
# 结束节点类型                                               制药建设项目
# 文本        6 HJ 611—2011 每个车间（或装置）及辅助设施的废水排放量（m3/d），主要污染物...
# Name: 65, dtype: object
# (_123:制药建设项目 {name: '\u8f85\u52a9\u8bbe\u65bd'})
# (_150:制药建设项目 {name: '\u56fa\u4f53\u5e9f\u7269'})
# 开始节点                                                 环境功能区划
# 开始节点类型                                               制药建设项目
# 关系                                                       规范
# 结束节点                                                 制药建设项目
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 66, dtype: object
# (_112:制药建设项目 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# 开始节点                                                 生态功能区划
# 开始节点类型                                               制药建设项目
# 关系                                                       约束
# 结束节点                                                 制药建设项目
# 结束节点类型                                               制药建设项目
# 文本        5.2 调查方法 现场踏查、相关部门走访、收集已有资料及图件（如水系图、土地利用图、环境功能...
# Name: 67, dtype: object
# (_166:制药建设项目 {name: '\u751f\u6001\u529f\u80fd\u533a\u5212'})
# (_100:制药建设项目 {name: '\u5236\u836f\u5efa\u8bbe\u9879\u76ee'})
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                      适用于
# 结束节点                                  化工、冶金、矿山采掘、农林、水利等建设项目
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 68, dtype: object
# None
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     不适用于
# 结束节点                                               核与辐射建设项目
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 69, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                GB15618
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 70, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                GB36600
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 71, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                              GB/T21010
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 72, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                  HJ2.1
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 73, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                  HJ2.2
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 74, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                  HJ2.3
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 75, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                   HJ19
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 76, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                 HJ25.1
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 77, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                 HJ25.2
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 78, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                  HJ169
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 79, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                  HJ610
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 80, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       引用
# 结束节点                                                HJ/T166
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 81, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       定义
# 结束节点                                                   土壤环境
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 82, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       定义
# 结束节点                                               土壤环境生态影响
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 83, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       定义
# 结束节点                                               土壤环境污染影响
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 84, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                         环境影响评价技术导则土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       定义
# 结束节点                                               土壤环境敏感目标
# 结束节点类型                                             土壤环境（试行）
# 文本        GB15618 土壤环境质量 农用地土壤污染风险管控标准（试行） GB36600 土壤环境质...
# Name: 85, dtype: object
# (_169:`土壤环境（试行）` {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u6280\u672f\u5bfc\u5219\u571f\u58e4\u73af\u5883'})
# None
# 开始节点                                                   土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       包含
# 结束节点                                               土壤环境生态影响
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 86, dtype: object
# (_211:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883'})
# (_200:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883\u751f\u6001\u5f71\u54cd'})
# 开始节点                                                   土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       包含
# 结束节点                                               土壤环境污染影响
# 结束节点类型                                             土壤环境（试行）
# 文本        环境影响评价技术导则 土壤环境 1 适用范围 本标准规定了土壤环境影响评价的一般性原则、工作...
# Name: 87, dtype: object
# (_211:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883'})
# (_201:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883\u6c61\u67d3\u5f71\u54cd'})
# 开始节点                                                   土壤环境
# 开始节点类型                                             土壤环境（试行）
# 关系                                                       关联
# 结束节点                                               土壤环境敏感目标
# 结束节点类型                                             土壤环境（试行）
# 文本        1 HJ 964—2018 3.4 土壤环境敏感目标 sensitive target of...
# Name: 88, dtype: object
# (_211:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883'})
# (_222:`土壤环境（试行）` {name: '\u571f\u58e4\u73af\u5883\u654f\u611f\u76ee\u6807'})
# 开始节点                                             HJ964—2018
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   规定评价等级
# 结束节点                                                  生态影响型
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 89, dtype: object
# None
# None
# 开始节点                                             HJ964—2018
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   规定评价等级
# 结束节点                                                  污染影响型
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 90, dtype: object
# (_212:`土壤环境（试行）` {name: 'HJ964\u20142018'})
# None
# 开始节点                                                     一级
# 开始节点类型                                             土壤环境（试行）
# 关系                                                  要求监测点数量
# 结束节点                                                 5个柱状样点
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 91, dtype: object
# None
# None
# 开始节点                                                     一级
# 开始节点类型                                             土壤环境（试行）
# 关系                                                  要求监测点数量
# 结束节点                                                 2个表层样点
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 92, dtype: object
# (_224:`土壤环境（试行）` {name: '\u4e00\u7ea7'})
# None
# 开始节点                                                     二级
# 开始节点类型                                             土壤环境（试行）
# 关系                                                  要求监测点数量
# 结束节点                                                 3个柱状样点
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 93, dtype: object
# None
# None
# 开始节点                                                     二级
# 开始节点类型                                             土壤环境（试行）
# 关系                                                  要求监测点数量
# 结束节点                                                 1个表层样点
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 94, dtype: object
# (_215:`土壤环境（试行）` {name: '\u4e8c\u7ea7'})
# None
# 开始节点                                                     三级
# 开始节点类型                                             土壤环境（试行）
# 关系                                                  要求监测点数量
# 结束节点                                                 3个表层样点
# 结束节点类型                                             土壤环境（试行）
# 文本        表6 现状监测布点类型与数量 评价工作等级 占地范围内 占地范围外 7 HJ 964—201...
# Name: 95, dtype: object
# None
# None
# 开始节点                                                   表层样点
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   参考取样方法
# 结束节点                                                HJ/T166
# 结束节点类型                                             土壤环境（试行）
# 文本        7.4.4 现状监测取样方法 表层样监测点及土壤剖面的土壤监测取样方法一般参照HJ/T166...
# Name: 96, dtype: object
# None
# (_210:`土壤环境（试行）` {name: 'HJ/T166'})
# 开始节点                                                   柱状样点
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   参考取样方法
# 结束节点                                                 HJ25.1
# 结束节点类型                                             土壤环境（试行）
# 文本        7.4.4 现状监测取样方法 表层样监测点及土壤剖面的土壤监测取样方法一般参照HJ/T166...
# Name: 97, dtype: object
# None
# (_206:`土壤环境（试行）` {name: 'HJ25.1'})
# 开始节点                                                   柱状样点
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   参考取样方法
# 结束节点                                                 HJ25.2
# 结束节点类型                                             土壤环境（试行）
# 文本        7.4.4 现状监测取样方法 表层样监测点及土壤剖面的土壤监测取样方法一般参照HJ/T166...
# Name: 98, dtype: object
# (_226:`土壤环境（试行）` {name: '\u67f1\u72b6\u6837\u70b9'})
# (_207:`土壤环境（试行）` {name: 'HJ25.2'})
# 开始节点                                                   基本因子
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     选自标准
# 结束节点                                                GB15618
# 结束节点类型                                             土壤环境（试行）
# 文本        a）基本因子为GB15618、GB36600中规定的基本项目，分别根据调查评价范围内的土地利...
# Name: 99, dtype: object
# None
# (_190:`土壤环境（试行）` {name: 'GB15618'})
# 开始节点                                                   基本因子
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     选自标准
# 结束节点                                                GB36600
# 结束节点类型                                             土壤环境（试行）
# 文本        a）基本因子为GB15618、GB36600中规定的基本项目，分别根据调查评价范围内的土地利...
# Name: 100, dtype: object
# (_227:`土壤环境（试行）` {name: '\u57fa\u672c\u56e0\u5b50'})
# (_171:`土壤环境（试行）` {name: 'GB36600'})
# 开始节点                                                   特征因子
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     确定依据
# 结束节点                                                    附录B
# 结束节点类型                                             土壤环境（试行）
# 文本        a）基本因子为GB15618、GB36600中规定的基本项目，分别根据调查评价范围内的土地利...
# Name: 101, dtype: object
# None
# None
# 开始节点                                                  标准指数法
# 开始节点类型                                             土壤环境（试行）
# 关系                                                   包含评价方法
# 结束节点                                                   统计分析
# 结束节点类型                                             土壤环境（试行）
# 文本        8 HJ 964—2018 7.5.3 评价方法 7.5.3.1 土壤环境质量现状评价应采用...
# Name: 102, dtype: object
# None
# None
# 开始节点                                              生态影响型建设项目
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     可能导致
# 结束节点                                                   土壤盐化
# 结束节点类型                                             土壤环境（试行）
# 文本        8.8.2 以下情况不能得出建设项目土壤环境影响可接受的结论： a）生态影响型建设项目：土壤...
# Name: 103, dtype: object
# None
# None
# 开始节点                                              生态影响型建设项目
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     可能导致
# 结束节点                                                   土壤酸化
# 结束节点类型                                             土壤环境（试行）
# 文本        8.8.2 以下情况不能得出建设项目土壤环境影响可接受的结论： a）生态影响型建设项目：土壤...
# Name: 104, dtype: object
# (_243:`土壤环境（试行）` {name: '\u751f\u6001\u5f71\u54cd\u578b\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                              生态影响型建设项目
# 开始节点类型                                             土壤环境（试行）
# 关系                                                     可能导致
# 结束节点                                                   土壤碱化
# 结束节点类型                                             土壤环境（试行）
# 文本        8.8.2 以下情况不能得出建设项目土壤环境影响可接受的结论： a）生态影响型建设项目：土壤...
# Name: 105, dtype: object
# (_243:`土壤环境（试行）` {name: '\u751f\u6001\u5f71\u54cd\u578b\u5efa\u8bbe\u9879\u76ee'})
# None
# 开始节点                                              污染影响型建设项目
# 开始节点类型                                             土壤环境（试行）
# 关系                                                      需符合
# 结束节点                                                GB15618
# 结束节点类型                                             土壤环境（试行）
# 文本        8.8.2 以下情况不能得出建设项目土壤环境影响可接受的结论： a）生态影响型建设项目：土壤...
# Name: 106, dtype: object
# None
# (_190:`土壤环境（试行）` {name: 'GB15618'})
# 开始节点                                              污染影响型建设项目
# 开始节点类型                                             土壤环境（试行）
# 关系                                                      需符合
# 结束节点                                                GB36600
# ...
# None
# 开始节点                                             环境影响因素识别结果
# 开始节点类型                                                 环评总纲
# 关系                                                     确定依据
# 结束节点                                                 环境保护目标
# 结束节点类型                                                 环评总纲
# 文本        3.8 环境保护目标的确定 依据环境影响因素识别结果，附图并列表说明评价范围内各环境要素涉及...
# Name: 273, dtype: object
# None
# (_458:环评总纲 {name: '\u73af\u5883\u4fdd\u62a4\u76ee\u6807'})
# 开始节点                                                 环境功能区划
# 开始节点类型                                                 环评总纲
# 关系                                                       确定
# 结束节点                                                 环境质量标准
# 结束节点类型                                                 环评总纲
# 文本        3.9 环境影响评价标准的确定 根据环境影响评价范围内各环境要素的环境功能区划确定各评价因子...
# Name: 274, dtype: object
# (_457:环评总纲 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# None
# 开始节点                                                 环境功能区划
# 开始节点类型                                                 环评总纲
# 关系                                                       确定
# 结束节点                                                污染物排放标准
# 结束节点类型                                                 环评总纲
# 文本        3.9 环境影响评价标准的确定 根据环境影响评价范围内各环境要素的环境功能区划确定各评价因子...
# Name: 275, dtype: object
# (_457:环评总纲 {name: '\u73af\u5883\u529f\u80fd\u533a\u5212'})
# None
# 开始节点                                         地方人民政府环境保护主管部门
# 开始节点类型                                                 环评总纲
# 关系                                                       确认
# 结束节点                                                 环境质量标准
# 结束节点类型                                                 环评总纲
# 文本        尚未划定环境功能区的区域，由地方人民政府环境保护主管 部门确认各环境要素应执行的环境质量标准...
# Name: 276, dtype: object
# None
# (_460:环评总纲 {name: '\u73af\u5883\u8d28\u91cf\u6807\u51c6'})
# 开始节点                                         地方人民政府环境保护主管部门
# 开始节点类型                                                 环评总纲
# 关系                                                       确认
# 结束节点                                                污染物排放标准
# 结束节点类型                                                 环评总纲
# 文本        尚未划定环境功能区的区域，由地方人民政府环境保护主管 部门确认各环境要素应执行的环境质量标准...
# Name: 277, dtype: object
# (_462:环评总纲 {name: '\u5730\u65b9\u4eba\u6c11\u653f\u5e9c\u73af\u5883\u4fdd\u62a4\u4e3b\u7ba1\u90e8\u95e8'})
# (_461:环评总纲 {name: '\u6c61\u67d3\u7269\u6392\u653e\u6807\u51c6'})
# 开始节点                                                 环境影响评价
# 开始节点类型                                                 环评总纲
# 关系                                                       采用
# 结束节点                                                   定量评价
# 结束节点类型                                                 环评总纲
# 文本        3.9 环境影响评价标准的确定 根据环境影响评价范围内各环境要素的环境功能区划确定各评价因子...
# Name: 278, dtype: object
# None
# None
# 开始节点                                                 环境影响评价
# 开始节点类型                                                 环评总纲
# 关系                                                       采用
# 结束节点                                                   定性评价
# 结束节点类型                                                 环评总纲
# 文本        3.9 环境影响评价标准的确定 根据环境影响评价范围内各环境要素的环境功能区划确定各评价因子...
# Name: 279, dtype: object
# (_427:环评总纲 {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7'})
# None
# 开始节点                         环境影响评价技术导则
# 开始节点类型                             环评总纲
# 关系                                   规定
# 结束节点                               评价方法
# 结束节点类型                             环评总纲
# 文本        环境影响评 价技术导则规定了评价方法的，应采用规定的方法。
# Name: 280, dtype: object
# None
# None
# 开始节点                                                   建设项目
# 开始节点类型                                                 环评总纲
# 关系                                                       进行
# 结束节点                                               建设方案环境比选
# 结束节点类型                                                 环评总纲
# 文本        3.11 建设方案的环境比选 建设项目有多个建设方案、涉及环境敏感区或环境影响显著时，应重点...
# Name: 281, dtype: object
# None
# None
# 开始节点                                               污染影响因素分析
# 开始节点类型                                                 环评总纲
# 关系                                                       遵循
# 结束节点                                                   清洁生产
# 结束节点类型                                                 环评总纲
# 文本        4.2 影响因素分析 4.2.1 污染影响因素分析 遵循清洁生产的理念，从工艺的环境友好性、...
# Name: 282, dtype: object
# None
# None
# 开始节点                                               污染影响因素分析
# 开始节点类型                                                 环评总纲
# 关系                                                       分析
# 结束节点                                                   产污节点
# 结束节点类型                                                 环评总纲
# 文本        4.2 影响因素分析 4.2.1 污染影响因素分析 遵循清洁生产的理念，从工艺的环境友好性、...
# Name: 283, dtype: object
# (_463:环评总纲 {name: '\u6c61\u67d3\u5f71\u54cd\u56e0\u7d20\u5206\u6790'})
# None
# 开始节点                                               污染影响因素分析
# 开始节点类型                                                 环评总纲
# 关系                                                       分析
# 结束节点                                                 末端治理措施
# 结束节点类型                                                 环评总纲
# 文本        4.2 影响因素分析 4.2.1 污染影响因素分析 遵循清洁生产的理念，从工艺的环境友好性、...
# Name: 284, dtype: object
# (_463:环评总纲 {name: '\u6c61\u67d3\u5f71\u54cd\u56e0\u7d20\u5206\u6790'})
# None
# 开始节点                                                 建设项目概况
# 开始节点类型                                                 环评总纲
# 关系                                                       包括
# 结束节点                                                   主体工程
# 结束节点类型                                                 环评总纲
# 文本        4 建设项目工程分析 4.1 建设项目概况 包括主体工程、辅助工程、公用工程、环保工程、储运...
# Name: 285, dtype: object
# None
# None
# 开始节点                                                 建设项目概况
# 开始节点类型                                                 环评总纲
# 关系                                                       包括
# 结束节点                                                   辅助工程
# 结束节点类型                                                 环评总纲
# 文本        4 建设项目工程分析 4.1 建设项目概况 包括主体工程、辅助工程、公用工程、环保工程、储运...
# Name: 286, dtype: object
# (_435:环评总纲 {name: '\u5efa\u8bbe\u9879\u76ee\u6982\u51b5'})
# None
# 开始节点                                                 建设项目概况
# 开始节点类型                                                 环评总纲
# 关系                                                       包括
# 结束节点                                                   公用工程
# 结束节点类型                                                 环评总纲
# 文本        4 建设项目工程分析 4.1 建设项目概况 包括主体工程、辅助工程、公用工程、环保工程、储运...
# Name: 287, dtype: object
# (_435:环评总纲 {name: '\u5efa\u8bbe\u9879\u76ee\u6982\u51b5'})
# None
# 开始节点                                                 建设项目概况
# 开始节点类型                                                 环评总纲
# 关系                                                       包括
# 结束节点                                                   环保工程
# 结束节点类型                                                 环评总纲
# 文本        4 建设项目工程分析 4.1 建设项目概况 包括主体工程、辅助工程、公用工程、环保工程、储运...
# Name: 288, dtype: object
# (_435:环评总纲 {name: '\u5efa\u8bbe\u9879\u76ee\u6982\u51b5'})
# None
# 开始节点                                                 建设项目特点
# 开始节点类型                                                 环评总纲
# 关系                                                       影响
# 结束节点                                               生态影响因素分析
# 结束节点类型                                                 环评总纲
# 文本        4.2.2 生态影响因素分析 结合建设项目特点和区域环境特征，分析建设项目建设和运行过程（包...
# Name: 289, dtype: object
# None
# None
# 开始节点                                                 区域环境特征
# 开始节点类型                                                 环评总纲
# 关系                                                       关联
# 结束节点                                               生态影响因素分析
# 结束节点类型                                                 环评总纲
# 文本        4.2.2 生态影响因素分析 结合建设项目特点和区域环境特征，分析建设项目建设和运行过程（包...
# Name: 290, dtype: object
# None
# (_441:环评总纲 {name: '\u751f\u6001\u5f71\u54cd\u56e0\u7d20\u5206\u6790'})
# 开始节点                                                   施工方式
# 开始节点类型                                                 环评总纲
# 关系                                                     作用因素
# 结束节点                                               生态影响因素分析
# 结束节点类型                                                 环评总纲
# 文本        4.2.2 生态影响因素分析 结合建设项目特点和区域环境特征，分析建设项目建设和运行过程（包...
# Name: 291, dtype: object
# None
# (_441:环评总纲 {name: '\u751f\u6001\u5f71\u54cd\u56e0\u7d20\u5206\u6790'})
# 开始节点                                                   运行过程
# 开始节点类型                                                 环评总纲
# 关系                                                     作用因素
# 结束节点                                               生态影响因素分析
# 结束节点类型                                                 环评总纲
# 文本        4.2.2 生态影响因素分析 结合建设项目特点和区域环境特征，分析建设项目建设和运行过程（包...
# Name: 292, dtype: object
# None
# (_441:环评总纲 {name: '\u751f\u6001\u5f71\u54cd\u56e0\u7d20\u5206\u6790'})
# 开始节点                                                    污染源
# 开始节点类型                                                 环评总纲
# 关系                                                       核算
# 结束节点                                                   排放强度
# 结束节点类型                                                 环评总纲
# 文本        4.3 污染源源强核算 4.3.1 根据污染物产生环节（包括生产、装卸、储存、运输）、产生方...
# Name: 293, dtype: object
# None
# None
# 开始节点                                                   环境要素
# 开始节点类型                                                 环评总纲
# 关系                                                     调查对象
# 结束节点                                                 环境现状调查
# 结束节点类型                                                 环评总纲
# 文本        5 环境现状调查与评价 5.1 基本要求 5 5.1.1 对与建设项目有密切关系的环境要素应...
# Name: 294, dtype: object
# None
# (_447:环评总纲 {name: '\u73af\u5883\u73b0\u72b6\u8c03\u67e5'})
# 开始节点                                                   监测资料
# 开始节点类型                                                 环评总纲
# 关系                                                     数据支持
# 结束节点                                                 环境现状调查
# 结束节点类型                                                 环评总纲
# 文本        对于自然环境的现状调查，可根据建设项目情况进行必要说明。5.1.2 充分收集和利用评价范围内...
# Name: 295, dtype: object
# None
# (_447:环评总纲 {name: '\u73af\u5883\u73b0\u72b6\u8c03\u67e5'})
# 开始节点                                                 环境保护目标
# 开始节点类型                                                 环评总纲
# 关系                                                     保护对象
# 结束节点                                                 环境现状调查
# 结束节点类型                                                 环评总纲
# 文本        5.3.2 环境保护目标调查 调查评价范围内的环境功能区划和主要的环境敏感区，详细了解环境保...
# Name: 296, dtype: object
# (_458:环评总纲 {name: '\u73af\u5883\u4fdd\u62a4\u76ee\u6807'})
# (_447:环评总纲 {name: '\u73af\u5883\u73b0\u72b6\u8c03\u67e5'})
# 开始节点                                                污染源源强核算
# 开始节点类型                                                 环评总纲
# 关系                                                       统计
# 结束节点                                                 污染物排放量
# 结束节点类型                                                 环评总纲
# 文本        4.3 污染源源强核算 4.3.1 根据污染物产生环节（包括生产、装卸、储存、运输）、产生方...
# Name: 297, dtype: object
# None
# None
# 开始节点                                                 环境现状调查
# 开始节点类型                                                 环评总纲
# 关系                                                     评价依据
# 结束节点                                                 环境质量现状
# 结束节点类型                                                 环评总纲
# 文本        5 环境现状调查与评价 5.1 基本要求 5 5.1.1 对与建设项目有密切关系的环境要素应...
# Name: 298, dtype: object
# (_447:环评总纲 {name: '\u73af\u5883\u73b0\u72b6\u8c03\u67e5'})
# None
# 开始节点                                              环境管理与监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                       包含
# 结束节点                                                 环境监测计划
# 结束节点类型                                                 环评总纲
# 文本        9 环境管理与监测计划 9.1 按建设项目建设阶段、生产运行、服务期满后（可根据项目情况选择...
# Name: 299, dtype: object
# None
# None
# 开始节点                                               环境影响评价结论
# 开始节点类型                                                 环评总纲
# 关系                                                       总结
# 结束节点                                             环境影响经济损益分析
# 结束节点类型                                                 环评总纲
# 文本        10 环境影响评价结论 对建设项目的建设概况、环境质量现状、污染物排放情况、主要环境影响、公...
# Name: 300, dtype: object
# None
# None
# 开始节点                                               环境影响评价结论
# 开始节点类型                                                 环评总纲
# 关系                                                       总结
# 结束节点                                              环境管理与监测计划
# 结束节点类型                                                 环评总纲
# 文本        10 环境影响评价结论 对建设项目的建设概况、环境质量现状、污染物排放情况、主要环境影响、公...
# Name: 301, dtype: object
# (_487:环评总纲 {name: '\u73af\u5883\u5f71\u54cd\u8bc4\u4ef7\u7ed3\u8bba'})
# (_485:环评总纲 {name: '\u73af\u5883\u7ba1\u7406\u4e0e\u76d1\u6d4b\u8ba1\u5212'})
# 开始节点                                                 环境监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                       监测
# 结束节点                                                    污染源
# 结束节点类型                                                 环评总纲
# 文本        包括工程组成及原辅材料组分要 求，建设项目拟采取的环境保护措施及主要运行参数，排放的污染物种...
# Name: 302, dtype: object
# (_486:环评总纲 {name: '\u73af\u5883\u76d1\u6d4b\u8ba1\u5212'})
# (_467:环评总纲 {name: '\u6c61\u67d3\u6e90'})
# 开始节点                                                 环境监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                       监测
# 结束节点                                                   环境质量
# 结束节点类型                                                 环评总纲
# 文本        9.4 环境监测计划应包括污染源监测计划和环境质量监测计划，内容包括监测因子、监测 网点布设...
# Name: 303, dtype: object
# (_486:环评总纲 {name: '\u73af\u5883\u76d1\u6d4b\u8ba1\u5212'})
# None
# 开始节点                                                 环境监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                   制定监测方案
# 结束节点                                                   生态影响
# 结束节点类型                                                 环评总纲
# 文本        c）对以生态影响为主的建设项目应提出生态监测方案。d）对存在较大潜在人群健康风险的建设项目，...
# Name: 304, dtype: object
# (_486:环评总纲 {name: '\u73af\u5883\u76d1\u6d4b\u8ba1\u5212'})
# None
# 开始节点                                              环境管理与监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                   明确运行参数
# 结束节点                                                 环境保护措施
# 结束节点类型                                                 环评总纲
# 文本        10 环境影响评价结论 对建设项目的建设概况、环境质量现状、污染物排放情况、主要环境影响、公...
# Name: 305, dtype: object
# (_485:环评总纲 {name: '\u73af\u5883\u7ba1\u7406\u4e0e\u76d1\u6d4b\u8ba1\u5212'})
# (_449:环评总纲 {name: '\u73af\u5883\u4fdd\u62a4\u63aa\u65bd'})
# 开始节点                                              环境管理与监测计划
# 开始节点类型                                                 环评总纲
# 关系                                                     管理要求
# 结束节点                                                  污染物排放
# 结束节点类型                                                 环评总纲
# 文本        10 环境影响评价结论 对建设项目的建设概况、环境质量现状、污染物排放情况、主要环境影响、公...
# Name: 306, dtype: object
# (_485:环评总纲 {name: '\u73af\u5883\u7ba1\u7406\u4e0e\u76d1\u6d4b\u8ba1\u5212'})
# None
# 开始节点                                             环境影响经济损益分析
# 开始节点类型                                                 环评总纲
# 关系                                                       核算
# 结束节点                                                直接和间接影响
# 结束节点类型                                                 环评总纲
# 文本        7 8 环境影响经济损益分析 以建设项目实施后的环境影响预测与环境质量现状进行比较，从环境影...
# Name: 307, dtype: object
# (_488:环评总纲 {name: '\u73af\u5883\u5f71\u54cd\u7ecf\u6d4e\u635f\u76ca\u5206\u6790'})
# None
# 开始节点                                             环境影响经济损益分析
# 开始节点类型                                                 环评总纲
# 关系                                                       评估
# 结束节点                                                有利和不利影响
# 结束节点类型                                                 环评总纲
# 文本         7 8 环境影响经济损益分析 以建设项目实施后的环境影响预测与环境质量现状进行比较，从环境...
# Name: 308, dtype: object
# (_488:环评总纲 {name: '\u73af\u5883\u5f71\u54cd\u7ecf\u6d4e\u635f\u76ca\u5206\u6790'})
# None
